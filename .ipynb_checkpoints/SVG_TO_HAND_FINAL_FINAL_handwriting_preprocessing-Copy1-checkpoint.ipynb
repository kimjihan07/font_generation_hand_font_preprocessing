# %%
# -*- coding: utf-8 -*-
from __future__ import print_function
from __future__ import absolute_import

import argparse
import sys
import numpy as np
import os
import glob
import cv2
from PIL import Image
from PIL import ImageDraw
from PIL import ImageFont
from PIL import ImageOps
from PIL import ImageFilter
from PIL import ImageEnhance
from cv2 import bilateralFilter
from pdf2image import convert_from_path
from utils import normalize_image
from matplotlib import pyplot as plt

# %%
def pdf_cropline(img, resize_fix):
    
    img = np.array(img)
    
    img = img[53:2255, 55:1592]
    print(img.shape)
    origin_h, origin_w = img.shape
    if origin_h > origin_w:
        resize_w = int(resize_fix * (origin_w/origin_h))
        resize_h = resize_fix
    elif origin_h == origin_w:
        resize_w = resize_fix
        resize_h = resize_fix
    else:
        resize_h = int(resize_fix * (origin_h/origin_w))
        resize_w = resize_fix
    

    img = cv2.resize(img, (resize_w, resize_h), Image.LANCZOS)
    img = Image.fromarray(img).convert('L')

    return img





def crop_fontline4(img, resize_fix):
    
    img = np.array(img)
    img_size = img.shape[0]
    
    full_white = img_size
    col_sum = np.where(np.sum(img, axis=0) < 255 * 128)
    row_sum = np.where(np.sum(img, axis=1) < 255 * 128)
    
    
    y1, y2 = row_sum[0][0], row_sum[0][-1]
    x1, x2 = col_sum[0][0], col_sum[0][-1]
    
    img = img[y1:y2, x1:x2]
    origin_h, origin_w = img.shape
    if origin_h > origin_w:
        resize_w = int(resize_fix * (origin_w/origin_h))
        resize_h = resize_fix
    elif origin_h == origin_w:
        resize_w = resize_fix
        resize_h = resize_fix
    else:
        resize_h = int(resize_fix * (origin_h/origin_w))
        resize_w = resize_fix
    

    img = cv2.resize(img, (resize_w, resize_h), Image.LANCZOS)
    
    #     print(type(img))
    img = Image.fromarray(img).convert('L')
    #     print(type(img))
    # plt.imshow(img)
    img = np.array(img)
    # print(img.size)
    # plt.imshow(img)
    img = add_padding(img, image_size=128, pad_value= 255)
    img = Image.fromarray(img).convert('L')
#     plt.imshow(img)
    return img

def crop_fontline1(img):
    
    img = np.array(img)
    img_size = img.shape[0]

    full_white = img_size
    col_sum = np.where(np.sum(img, axis=0) < 255 * 128)
    row_sum = np.where(np.sum(img, axis=1) < 255 * 128)
    
    
    y1, y2 = row_sum[0][0], row_sum[0][-1]
    x1, x2 = col_sum[0][0], col_sum[0][-1]
#     print(y1,y2)
#     print(x1,x2)
    img = img[y1:y2, x1:x2]
    img = add_padding(img, image_size=128, pad_value= 255)
    img = Image.fromarray(img).convert('L')
    return img


def add_padding(img, image_size=128, pad_value=None):
    #인풋 넘파이 
    height, width = img.shape
    if not pad_value:
        pad_value = 255
    
    # Adding padding of x axis - left, right
    pad_x_width = (image_size - width) // 2
    pad_x = np.full((height, pad_x_width), pad_value, dtype=np.float32)
    img = np.concatenate((pad_x, img), axis=1)
    img = np.concatenate((img, pad_x), axis=1)
    
    width = img.shape[1]

    # Adding padding of y axis - top, bottom
    pad_y_height = (image_size - height) // 2
    pad_y = np.full((pad_y_height, width), pad_value, dtype=np.float32)
    img = np.concatenate((pad_y, img), axis=0)
    img = np.concatenate((img, pad_y), axis=0)
    
    # Match to original image size
    width = img.shape[1]
    if img.shape[0] % 2:
        pad = np.full((1, width), pad_value, dtype=np.float32)
        img = np.concatenate((pad, img), axis=0)
    height = img.shape[0]
    if img.shape[1] % 2:
        pad = np.full((height, 1), pad_value, dtype=np.float32)
        img = np.concatenate((pad, img), axis=1)
    
    return img

def grbtogray(img_path):
    img_path
    img= cv2.imread(img_path,cv2.IMREAD_UNCHANGED)
    print(img.shape)
#     img_gray = 255 - img[:, :, 3]
    img_gray = img
    img_gray.shape

    hand_wr = Image.fromarray(img_gray).convert('L')
    img = hand_wr.resize((128,128), Image.LANCZOS)
    return img



def enhanc(img):
    enhancer = ImageEnhance.Contrast(img)
    cropped_image = enhancer.enhance(1)
    cropped_image = np.array(cropped_image)
    centered_image = Image.fromarray(cropped_image.astype(np.uint8))
    centered_image = bilateralFilter(cropped_image, 15, 15, 30)
    centered_image = Image.fromarray(centered_image).convert('L')
    return centered_image

# %%
pages = convert_from_path('/home/piai/Ai/project/makeme/210_template_kh.pdf') # pdf파일을 이미지로 변환 list 형태로 저장
scr='/home/piai/Ai/project/handwriter/font_generation/font/source/NanumGothic.ttf'
scr_font = ImageFont.truetype(scr, size = 80)
charset = '/home/piai/Ai/project/makeme/random210_cha.txt'
charset = open(charset).read().splitlines()
idx = '/home/piai/Ai/project/makeme/random210_idx.txt'
idx = open(idx).read().splitlines()
rows = 28
cols = 15
m = 1
n = 0
exct = [4,5,8,9] 
pdf_page=0
for page in pages: # pages list에서 

    page = page.convert('L')
    page = pdf_cropline(page, 6606)

    plt.imshow(page)
    np_page = np.array(page) # 이미지로 변환된 pdf 파일을 array로 저장
    cropped_img = np.where(np_page < 191,0,255) #127보다 작으면 0 ,127보다 크면 255
    pdf = Image.fromarray(cropped_img.astype(np.uint8))
    plt.imshow(pdf)
#         pdf.save('check_template_final_con.png')
    n += 1

    width, height = pdf.size
    cell_width = width/float(cols)
    cell_height = height/float(rows)
    
    width_margin = cell_width * 0.005
    height_margin = cell_height * 0.005

    if pdf_page ==1:
        for j in range(0,rows):
            if j == 4:
                    break

            elif j % 2 == 0:
                for i in range(0, cols):
                    left = i * cell_width
                    upper = j * 235.5
                    right = left + cell_width
                    lower = upper + 165
                    connect_num = lower
#                     print("짝수 --1pdf_page: {}, j: {}, i: {}, m: {}".format(pdf_page, j, i, m))
                    
             
                     
            elif j % 2 != 0:

                for i in range(0,cols):
                    

                    left = i * cell_width
                    upper = connect_num 
                    right = left + cell_width
                    lower = upper + 306
                    cropped_image = pdf.crop((left,upper,right,lower))
                    print(cropped_image.size)
                    cropped_image.save("/home/piai/Ai/project/makeme/KH_fonts/kh ({}).png".format(m))
                    print(m)
                    m +=1
                    print("홀수 --pdf_page: {}, j: {}, i: {}, left : {}, upper: {}, right: {}, lower: {}".format(pdf_page, j, i, left, right, upper, lower))
    
    else:
        
        for j in range(0,rows):
            if j % 2 == 0: # 짝수 행 타겟 소스 행

                for i in range(0, cols):

                    left = i * cell_width
                    upper = j * 235.5
                    right = left + cell_width
                    lower = upper + 165
                    connect_num = lower
                    
                    ch = charset[m]
                    target = Image.new("RGB", (128,128), (255, 255, 255)).convert('L')
                    draw = ImageDraw.Draw(target)
                    draw.text((20, 20), ch, (0), font=scr_font)
#                     target.save("/home/piai/Ai/project/makeme/HW_target_fonts_os20_sc_70/타겟_{}_{}_{}_cropped_img.png".format(pdf_page,j,i))
#                     print("짝수 --2pdf_page: {}, j: {}, i: {}, m: {}".format(pdf_page, j, i, m))
                     


            elif j % 2 != 0: # 홀수 행 핸드라이팅 행              

                for i in range(0,cols):


                    left = i * cell_width
                    upper = connect_num 
                    right = left + cell_width
                    lower = upper + 306
                    cropped_image = pdf.crop((left,upper,right,lower))
                    print(cropped_image.size)
#                     cropped_image = cropped_image.resize((128,128), Image.LANCZOS)
#                     plt.imshow(cropped_image)
                    cropped_image.save("/home/piai/Ai/project/makeme/KH_fonts/kh ({}).png".format(m))
                    print(m)
                    m += 1                    
                    
#                     print("홀수 --pdf_page: {}, j: {}, i: {}, left : {}, upper: {}, right: {}, lower: {}, connect_num: {}".format(pdf_page, j, i, left, right, upper, lower, connect_num))
    pdf_page += 1
print('폰트 생성이 완료되었습니다.')
# Out:
# (2202, 1537)
# (307, 306)
# 1
# (308, 306)
# 2
# (307, 306)
# 3
# (308, 306)
# 4
# (307, 306)
# 5
# (307, 306)
# 6
# (308, 306)
# 7
# (307, 306)
# 8
# (308, 306)
# 9
# (307, 306)
# 10
# (307, 306)
# 11
# (308, 306)
# 12
# (307, 306)
# 13
# (308, 306)
# 14
# (307, 306)
# 15
# (307, 306)
# 16
# (308, 306)
# 17
# (307, 306)
# 18
# (308, 306)
# 19
# (307, 306)
# 20
# (307, 306)
# 21
# (308, 306)
# 22
# (307, 306)
# 23
# (308, 306)
# 24
# (307, 306)
# 25
# (307, 306)
# 26
# (308, 306)
# 27
# (307, 306)
# 28
# (308, 306)
# 29
# (307, 306)
# 30
# (307, 306)
# 31
# (308, 306)
# 32
# (307, 306)
# 33
# (308, 306)
# 34
# (307, 306)
# 35
# (307, 306)
# 36
# (308, 306)
# 37
# (307, 306)
# 38
# (308, 306)
# 39
# (307, 306)
# 40
# (307, 306)
# 41
# (308, 306)
# 42
# (307, 306)
# 43
# (308, 306)
# 44
# (307, 306)
# 45
# (307, 306)
# 46
# (308, 306)
# 47
# (307, 306)
# 48
# (308, 306)
# 49
# (307, 306)
# 50
# (307, 306)
# 51
# (308, 306)
# 52
# (307, 306)
# 53
# (308, 306)
# 54
# (307, 306)
# 55
# (307, 306)
# 56
# (308, 306)
# 57
# (307, 306)
# 58
# (308, 306)
# 59
# (307, 306)
# 60
# (307, 306)
# 61
# (308, 306)
# 62
# (307, 306)
# 63
# (308, 306)
# 64
# (307, 306)
# 65
# (307, 306)
# 66
# (308, 306)
# 67
# (307, 306)
# 68
# (308, 306)
# 69
# (307, 306)
# 70
# (307, 306)
# 71
# (308, 306)
# 72
# (307, 306)
# 73
# (308, 306)
# 74
# (307, 306)
# 75
# (307, 306)
# 76
# (308, 306)
# 77
# (307, 306)
# 78
# (308, 306)
# 79
# (307, 306)
# 80
# (307, 306)
# 81
# (308, 306)
# 82
# (307, 306)
# 83
# (308, 306)
# 84
# (307, 306)
# 85
# (307, 306)
# 86
# (308, 306)
# 87
# (307, 306)
# 88
# (308, 306)
# 89
# (307, 306)
# 90
# (307, 306)
# 91
# (308, 306)
# 92
# (307, 306)
# 93
# (308, 306)
# 94
# (307, 306)
# 95
# (307, 306)
# 96
# (308, 306)
# 97
# (307, 306)
# 98
# (308, 306)
# 99
# (307, 306)
# 100
# (307, 306)
# 101
# (308, 306)
# 102
# (307, 306)
# 103
# (308, 306)
# 104
# (307, 306)
# 105
# (307, 306)
# 106
# (308, 306)
# 107
# (307, 306)
# 108
# (308, 306)
# 109
# (307, 306)
# 110
# (307, 306)
# 111
# (308, 306)
# 112
# (307, 306)
# 113
# (308, 306)
# 114
# (307, 306)
# 115
# (307, 306)
# 116
# (308, 306)
# 117
# (307, 306)
# 118
# (308, 306)
# 119
# (307, 306)
# 120
# (307, 306)
# 121
# (308, 306)
# 122
# (307, 306)
# 123
# (308, 306)
# 124
# (307, 306)
# 125
# (307, 306)
# 126
# (308, 306)
# 127
# (307, 306)
# 128
# (308, 306)
# 129
# (307, 306)
# 130
# (307, 306)
# 131
# (308, 306)
# 132
# (307, 306)
# 133
# (308, 306)
# 134
# (307, 306)
# 135
# (307, 306)
# 136
# (308, 306)
# 137
# (307, 306)
# 138
# (308, 306)
# 139
# (307, 306)
# 140
# (307, 306)
# 141
# (308, 306)
# 142
# (307, 306)
# 143
# (308, 306)
# 144
# (307, 306)
# 145
# (307, 306)
# 146
# (308, 306)
# 147
# (307, 306)
# 148
# (308, 306)
# 149
# (307, 306)
# 150
# (307, 306)
# 151
# (308, 306)
# 152
# (307, 306)
# 153
# (308, 306)
# 154
# (307, 306)
# 155
# (307, 306)
# 156
# (308, 306)
# 157
# (307, 306)
# 158
# (308, 306)
# 159
# (307, 306)
# 160
# (307, 306)
# 161
# (308, 306)
# 162
# (307, 306)
# 163
# (308, 306)
# 164
# (307, 306)
# 165
# (307, 306)
# 166
# (308, 306)
# 167
# (307, 306)
# 168
# (308, 306)
# 169
# (307, 306)
# 170
# (307, 306)
# 171
# (308, 306)
# 172
# (307, 306)
# 173
# (308, 306)
# 174
# (307, 306)
# 175
# (307, 306)
# 176
# (308, 306)
# 177
# (307, 306)
# 178
# (308, 306)
# 179
# (307, 306)
# 180
# (307, 306)
# 181
# (308, 306)
# 182
# (307, 306)
# 183
# (308, 306)
# 184
# (307, 306)
# 185
# (307, 306)
# 186
# (308, 306)
# 187
# (307, 306)
# 188
# (308, 306)
# 189
# (307, 306)
# 190
# (307, 306)
# 191
# (308, 306)
# 192
# (307, 306)
# 193
# (308, 306)
# 194
# (307, 306)
# 195
# (307, 306)
# 196
# (308, 306)
# 197
# (307, 306)
# 198
# (308, 306)
# 199
# (307, 306)
# 200
# (307, 306)
# 201
# (308, 306)
# 202
# (307, 306)
# 203
# (308, 306)
# 204
# (307, 306)
# 205
# (307, 306)
# 206
# (308, 306)
# 207
# (307, 306)
# 208
# (308, 306)
# 209
# (307, 306)
# 210
# (2202, 1537)
# (307, 306)
# 211
# 홀수 --pdf_page: 1, j: 1, i: 0, left : 0.0, upper: 307.4, right: 165.0, lower: 471.0
# (308, 306)
# 212
# 홀수 --pdf_page: 1, j: 1, i: 1, left : 307.4, upper: 614.8, right: 165.0, lower: 471.0
# (307, 306)
# 213
# 홀수 --pdf_page: 1, j: 1, i: 2, left : 614.8, upper: 922.1999999999999, right: 165.0, lower: 471.0
# (308, 306)
# 214
# 홀수 --pdf_page: 1, j: 1, i: 3, left : 922.1999999999999, upper: 1229.6, right: 165.0, lower: 471.0
# (307, 306)
# 215
# 홀수 --pdf_page: 1, j: 1, i: 4, left : 1229.6, upper: 1537.0, right: 165.0, lower: 471.0
# (307, 306)
# 216
# 홀수 --pdf_page: 1, j: 1, i: 5, left : 1537.0, upper: 1844.4, right: 165.0, lower: 471.0
# (308, 306)
# 217
# 홀수 --pdf_page: 1, j: 1, i: 6, left : 1844.3999999999999, upper: 2151.7999999999997, right: 165.0, lower: 471.0
# (307, 306)
# 218
# 홀수 --pdf_page: 1, j: 1, i: 7, left : 2151.7999999999997, upper: 2459.2, right: 165.0, lower: 471.0
# (308, 306)
# 219
# 홀수 --pdf_page: 1, j: 1, i: 8, left : 2459.2, upper: 2766.6, right: 165.0, lower: 471.0
# (307, 306)
# 220
# 홀수 --pdf_page: 1, j: 1, i: 9, left : 2766.6, upper: 3074.0, right: 165.0, lower: 471.0
# (307, 306)
# 221
# 홀수 --pdf_page: 1, j: 1, i: 10, left : 3074.0, upper: 3381.4, right: 165.0, lower: 471.0
# (308, 306)
# 222
# 홀수 --pdf_page: 1, j: 1, i: 11, left : 3381.3999999999996, upper: 3688.7999999999997, right: 165.0, lower: 471.0
# (307, 306)
# 223
# 홀수 --pdf_page: 1, j: 1, i: 12, left : 3688.7999999999997, upper: 3996.2, right: 165.0, lower: 471.0
# (308, 306)
# 224
# 홀수 --pdf_page: 1, j: 1, i: 13, left : 3996.2, upper: 4303.599999999999, right: 165.0, lower: 471.0
# (307, 306)
# 225
# 홀수 --pdf_page: 1, j: 1, i: 14, left : 4303.599999999999, upper: 4610.999999999999, right: 165.0, lower: 471.0
# (307, 306)
# 226
# 홀수 --pdf_page: 1, j: 3, i: 0, left : 0.0, upper: 307.4, right: 636.0, lower: 942.0
# (308, 306)
# 227
# 홀수 --pdf_page: 1, j: 3, i: 1, left : 307.4, upper: 614.8, right: 636.0, lower: 942.0
# (307, 306)
# 228
# 홀수 --pdf_page: 1, j: 3, i: 2, left : 614.8, upper: 922.1999999999999, right: 636.0, lower: 942.0
# (308, 306)
# 229
# 홀수 --pdf_page: 1, j: 3, i: 3, left : 922.1999999999999, upper: 1229.6, right: 636.0, lower: 942.0
# (307, 306)
# 230
# 홀수 --pdf_page: 1, j: 3, i: 4, left : 1229.6, upper: 1537.0, right: 636.0, lower: 942.0
# (307, 306)
# 231
# 홀수 --pdf_page: 1, j: 3, i: 5, left : 1537.0, upper: 1844.4, right: 636.0, lower: 942.0
# (308, 306)
# 232
# 홀수 --pdf_page: 1, j: 3, i: 6, left : 1844.3999999999999, upper: 2151.7999999999997, right: 636.0, lower: 942.0
# (307, 306)
# 233
# 홀수 --pdf_page: 1, j: 3, i: 7, left : 2151.7999999999997, upper: 2459.2, right: 636.0, lower: 942.0
# (308, 306)
# 234
# 홀수 --pdf_page: 1, j: 3, i: 8, left : 2459.2, upper: 2766.6, right: 636.0, lower: 942.0
# (307, 306)
# 235
# 홀수 --pdf_page: 1, j: 3, i: 9, left : 2766.6, upper: 3074.0, right: 636.0, lower: 942.0
# (307, 306)
# 236
# 홀수 --pdf_page: 1, j: 3, i: 10, left : 3074.0, upper: 3381.4, right: 636.0, lower: 942.0
# (308, 306)
# 237
# 홀수 --pdf_page: 1, j: 3, i: 11, left : 3381.3999999999996, upper: 3688.7999999999997, right: 636.0, lower: 942.0
# (307, 306)
# 238
# 홀수 --pdf_page: 1, j: 3, i: 12, left : 3688.7999999999997, upper: 3996.2, right: 636.0, lower: 942.0
# (308, 306)
# 239
# 홀수 --pdf_page: 1, j: 3, i: 13, left : 3996.2, upper: 4303.599999999999, right: 636.0, lower: 942.0
# (307, 306)
# 240
# 홀수 --pdf_page: 1, j: 3, i: 14, left : 4303.599999999999, upper: 4610.999999999999, right: 636.0, lower: 942.0
# 폰트 생성이 완료되었습니다.

# %%
pages = convert_from_path('/home/piai/Ai/project/makeme/210_template_HW.pdf') # pdf파일을 이미지로 변환 list 형태로 저장
scr='/home/piai/Ai/project/handwriter/font_generation/font/source/NanumGothic.ttf'
scr_font = ImageFont.truetype(scr, size = 80)
charset = '/home/piai/Ai/project/makeme/random210_cha.txt'
charset = open(charset).read().splitlines()
idx = '/home/piai/Ai/project/makeme/random210_idx.txt'
idx = open(idx).read().splitlines()
rows = 28
cols = 15
m = 0
exct = [4,5,8,9] 

rows = 56
cols = 15
pdf_page=0
c=0
a=0
e=0
d=0
n=0
t=1
pages = [0,1]
charset = '/home/piai/Ai/project/makeme/random210_cha.txt'
charset = open(charset).read().splitlines()
idx = '/home/piai/Ai/project/makeme/random210_idx.txt'
idx = open(idx).read().splitlines()
for page in pages:
    if page == 1:
        
        for j in range(0, rows):
            if e == 3:
                break
            
            else:
                d = 2*j

                e = 2*j + 1
                for i in range(0, cols):
#                     print("page: {}, d:{}, e: {}, i: {}, n: {}, t: {} ".format(page,d,e,i,n,t))
                    
                    hand_wr = "/home/piai/Ai/project/makeme/KH_fonts/kh ({}).png".format(t)
                    print(hand_wr)
                    hand_wr = grbtogray(hand_wr)
                    print("t: {} 그림 :{}".format(t, hand_wr.size))
                    hand_wr = np.array(hand_wr)
                    hand_wr = np.where(np.sum(hand_wr , axis=0) == 0 , 255 , hand_wr)
                    print(hand_wr)
                    hand_wr = crop_fontline4(hand_wr, 85)
                    hand_wr = enhanc(hand_wr)
                    hand_wr = np.array(hand_wr)
                    hand_wr = np.where(np.sum(hand_wr , axis=0) == 0 , 255 , hand_wr)
#                     hand_wr = np.where(hand_wr < 40,0,255)
                    hand_wr = np.where(np.sum(hand_wr , axis=0) == 0 , 255 , hand_wr)
                    hand_wr = Image.fromarray(hand_wr.astype(np.uint8))
                    hand_wr.save('/home/piai/Ai/project/makeme/KH_fonts_resize/kh ({}).png'.format(t))

                    
                    target = Image.open("/home/piai/Ai/project/makeme/Target_fonts/타겟_{}_{}_{}_cropped_img.png".format(page,d,i))
#                     target = crop_fontline1(target)
                    target = np.array(target)
                    target = Image.fromarray(target).convert('L')
                    hand_wr_size =hand_wr.size
                    target_size =target.size
                    merge_img = Image.new('L', (2*hand_wr_size[0],hand_wr_size[1]))
                    merge_img.paste(hand_wr, (0,0))
                    merge_img.paste(target,(hand_wr_size[0],0))
                    merge_img.save("/home/piai/Ai/project/makeme/KH_fonts_merge_FN/1_{}.png".format(idx[n]),"png")
                    print("t : {}".format(t))
                    n+=1
                    t +=1
                    
#                     plt.imshow(merge_img) 
                             
    else:
        for j in range(0, rows):
            if a ==26:
                break
            else:    
                a = 2*j

                c = 2*j + 1

                for i in range(0, cols):
                    
#                     print("page: {}, a:{}, c: {}, i: {}, n: {}, t: {} ".format(page,a,c,i,n,t))
                    hand_wr = "/home/piai/Ai/project/makeme/KH_fonts/kh ({}).png".format(t)
                    hand_wr = grbtogray(hand_wr)
#                     hand_wr.save('/home/piai/Ai/project/makeme/HW_fonts_resize/hw ({}).png'.format(t))            
                    hand_wr = np.array(hand_wr)
                    hand_wr = np.where(np.sum(hand_wr , axis=0) == 0 , 255 , hand_wr)
                    hand_wr = crop_fontline4(hand_wr, 85)
                    hand_wr = enhanc(hand_wr)
                    hand_wr = np.array(hand_wr)
                    
#                     hand_wr = np.where(hand_wr < 40,0,255)
                    hand_wr = np.where(np.sum(hand_wr , axis=0) == 0 , 255 , hand_wr)
                    hand_wr = np.where(np.sum(hand_wr , axis=0) == 0 , 255 , hand_wr)
#                     hand_wr = np.where(np.sum(hand_wr , axis=0) == 0 , 255 , hand_wr)
#                     hand_wr = np.where(np.sum(hand_wr , axis=0) == 0 , 255 , hand_wr)
                    hand_wr = Image.fromarray(hand_wr.astype(np.uint8))
                    hand_wr.save('/home/piai/Ai/project/makeme/KH_fonts_resize/kh ({}).png'.format(t))
                    
        
                    target = Image.open("/home/piai/Ai/project/makeme/Target_fonts/타겟_{}_{}_{}_cropped_img.png".format(page,a,i))
#                     target = crop_fontline1(target)
                    target = np.array(target)
                    target = Image.fromarray(target).convert('L')
                    hand_wr_size =hand_wr.size
                    target_size =target.size
#                     
                    merge_img = Image.new('L', (2*hand_wr_size[0],hand_wr_size[1]))
                    merge_img.paste(hand_wr, (0,0))
                    merge_img.paste(target,(hand_wr_size[0],0))

                    merge_img.save("/home/piai/Ai/project/makeme/KH_fonts_merge_FN/1_{}.png".format(idx[n]),"png")
                    print("t : {}".format(t))
                    n+=1
                    t +=1
#                     plt.imshow(merge_img)
print("이미지 생성완료")
# Out:
# (306, 307)
# t : 1
# (306, 308)
# t : 2
# (306, 307)
# t : 3
# (306, 308)
# t : 4
# (306, 307)
# t : 5
# (306, 307)
# t : 6
# (306, 308)
# t : 7
# (306, 307)
# t : 8
# (306, 308)
# t : 9
# (306, 307)
# t : 10
# (306, 307)
# t : 11
# (306, 308)
# t : 12
# (306, 307)
# t : 13
# (306, 308)
# t : 14
# (306, 307)
# t : 15
# (306, 307)
# t : 16
# (306, 308)
# t : 17
# (306, 307)
# t : 18
# (306, 308)
# t : 19
# (306, 307)
# t : 20
# (306, 307)
# t : 21
# (306, 308)
# t : 22
# (306, 307)
# t : 23
# (306, 308)
# t : 24
# (306, 307)
# t : 25
# (306, 307)
# t : 26
# (306, 308)
# t : 27
# (306, 307)
# t : 28
# (306, 308)
# t : 29
# (306, 307)
# t : 30
# (306, 307)
# t : 31
# (306, 308)
# t : 32
# (306, 307)
# t : 33
# (306, 308)
# t : 34
# (306, 307)
# t : 35
# (306, 307)
# t : 36
# (306, 308)
# t : 37
# (306, 307)
# t : 38
# (306, 308)
# t : 39
# (306, 307)
# t : 40
# (306, 307)
# t : 41
# (306, 308)
# t : 42
# (306, 307)
# t : 43
# (306, 308)
# t : 44
# (306, 307)
# t : 45
# (306, 307)
# t : 46
# (306, 308)
# t : 47
# (306, 307)
# t : 48
# (306, 308)
# t : 49
# (306, 307)
# t : 50
# (306, 307)
# t : 51
# (306, 308)
# t : 52
# (306, 307)
# t : 53
# (306, 308)
# t : 54
# (306, 307)
# t : 55
# (306, 307)
# t : 56
# (306, 308)
# t : 57
# (306, 307)
# t : 58
# (306, 308)
# t : 59
# (306, 307)
# t : 60
# (306, 307)
# t : 61
# (306, 308)
# t : 62
# (306, 307)
# t : 63
# (306, 308)
# t : 64
# (306, 307)
# t : 65
# (306, 307)
# t : 66
# (306, 308)
# t : 67
# (306, 307)
# t : 68
# (306, 308)
# t : 69
# (306, 307)
# t : 70
# (306, 307)
# t : 71
# (306, 308)
# t : 72
# (306, 307)
# t : 73
# (306, 308)
# t : 74
# (306, 307)
# t : 75
# (306, 307)
# t : 76
# (306, 308)
# t : 77
# (306, 307)
# t : 78
# (306, 308)
# t : 79
# (306, 307)
# t : 80
# (306, 307)
# t : 81
# (306, 308)
# t : 82
# (306, 307)
# t : 83
# (306, 308)
# t : 84
# (306, 307)
# t : 85
# (306, 307)
# t : 86
# (306, 308)
# t : 87
# (306, 307)
# t : 88
# (306, 308)
# t : 89
# (306, 307)
# t : 90
# (306, 307)
# t : 91
# (306, 308)
# t : 92
# (306, 307)
# t : 93
# (306, 308)
# t : 94
# (306, 307)
# t : 95
# (306, 307)
# t : 96
# (306, 308)
# t : 97
# (306, 307)
# t : 98
# (306, 308)
# t : 99
# (306, 307)
# t : 100
# (306, 307)
# t : 101
# (306, 308)
# t : 102
# (306, 307)
# t : 103
# (306, 308)
# t : 104
# (306, 307)
# t : 105
# (306, 307)
# t : 106
# (306, 308)
# t : 107
# (306, 307)
# t : 108
# (306, 308)
# t : 109
# (306, 307)
# t : 110
# (306, 307)
# t : 111
# (306, 308)
# t : 112
# (306, 307)
# t : 113
# (306, 308)
# t : 114
# (306, 307)
# t : 115
# (306, 307)
# t : 116
# (306, 308)
# t : 117
# (306, 307)
# t : 118
# (306, 308)
# t : 119
# (306, 307)
# t : 120
# (306, 307)
# t : 121
# (306, 308)
# t : 122
# (306, 307)
# t : 123
# (306, 308)
# t : 124
# (306, 307)
# t : 125
# (306, 307)
# t : 126
# (306, 308)
# t : 127
# (306, 307)
# t : 128
# (306, 308)
# t : 129
# (306, 307)
# t : 130
# (306, 307)
# t : 131
# (306, 308)
# t : 132
# (306, 307)
# t : 133
# (306, 308)
# t : 134
# (306, 307)
# t : 135
# (306, 307)
# t : 136
# (306, 308)
# t : 137
# (306, 307)
# t : 138
# (306, 308)
# t : 139
# (306, 307)
# t : 140
# (306, 307)
# t : 141
# (306, 308)
# t : 142
# (306, 307)
# t : 143
# (306, 308)
# t : 144
# (306, 307)
# t : 145
# (306, 307)
# t : 146
# (306, 308)
# t : 147
# (306, 307)
# t : 148
# (306, 308)
# t : 149
# (306, 307)
# t : 150
# (306, 307)
# t : 151
# (306, 308)
# t : 152
# (306, 307)
# t : 153
# (306, 308)
# t : 154
# (306, 307)
# t : 155
# (306, 307)
# t : 156
# (306, 308)
# t : 157
# (306, 307)
# t : 158
# (306, 308)
# t : 159
# (306, 307)
# t : 160
# (306, 307)
# t : 161
# (306, 308)
# t : 162
# (306, 307)
# t : 163
# (306, 308)
# t : 164
# (306, 307)
# t : 165
# (306, 307)
# t : 166
# (306, 308)
# t : 167
# (306, 307)
# t : 168
# (306, 308)
# t : 169
# (306, 307)
# t : 170
# (306, 307)
# t : 171
# (306, 308)
# t : 172
# (306, 307)
# t : 173
# (306, 308)
# t : 174
# (306, 307)
# t : 175
# (306, 307)
# t : 176
# (306, 308)
# t : 177
# (306, 307)
# t : 178
# (306, 308)
# t : 179
# (306, 307)
# t : 180
# (306, 307)
# t : 181
# (306, 308)
# t : 182
# (306, 307)
# t : 183
# (306, 308)
# t : 184
# (306, 307)
# t : 185
# (306, 307)
# t : 186
# (306, 308)
# t : 187
# (306, 307)
# t : 188
# (306, 308)
# t : 189
# (306, 307)
# t : 190
# (306, 307)
# t : 191
# (306, 308)
# t : 192
# (306, 307)
# t : 193
# (306, 308)
# t : 194
# (306, 307)
# t : 195
# (306, 307)
# t : 196
# (306, 308)
# t : 197
# (306, 307)
# t : 198
# (306, 308)
# t : 199
# (306, 307)
# t : 200
# (306, 307)
# t : 201
# (306, 308)
# t : 202
# (306, 307)
# t : 203
# (306, 308)
# t : 204
# (306, 307)
# t : 205
# (306, 307)
# t : 206
# (306, 308)
# t : 207
# (306, 307)
# t : 208
# (306, 308)
# t : 209
# (306, 307)
# t : 210
# /home/piai/Ai/project/makeme/KH_fonts/kh (211).png
# (306, 307)
# t: 211 그림 :(128, 128)
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-140-4466ba1fe9a6> in <module>
#      46                     hand_wr = np.where(np.sum(hand_wr , axis=0) == 0 , 255 , hand_wr)
#      47                     print(hand_wr)
# ---> 48                     hand_wr = crop_fontline4(hand_wr, 85)
#      49                     hand_wr = enhanc(hand_wr)
#      50                     hand_wr = np.array(hand_wr)
#
# <ipython-input-114-a6c17f431cf6> in crop_fontline4(img, resize_fix)
#      36
#      37
# ---> 38     y1, y2 = row_sum[0][0], row_sum[0][-1]
#      39     x1, x2 = col_sum[0][0], col_sum[0][-1]
#      40
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
pd = Image.open('check_template_final.jpeg')
# plt.imshow(pd)
# pd.size
pd =pdf_cropline(pd, 7000)
pd =np.array(pd)
pd = np.where(np.sum(pd , axis=0) == 0 , 255 , pd)
pdf = Image.fromarray(pd.astype(np.uint8))
print(pdf.size)
pdf.save('pdf_check7.png')

# pd.size
# plt.imshow(pd)

# pd.save('pdf_check6.png')
# Out:
# (2202, 1537)
# (4886, 7000)
